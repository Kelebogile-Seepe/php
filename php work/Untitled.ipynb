# %%
print("Welocome to programming")
name = input("enter your name")
print(name)
# Out:
# Welocome to programming
# enter your name kelebogile
# kelebogile

# %%
number1 = int(input("Enter your firsst number"))
number2 = int(input("Enter your second number"))
answer = number1 + number2
print("you number is equals to", answer)
# Out:
# Enter your firsst number 70
# Enter your second number 40
# ypu number is equals to 110

# %%
name = input("Enter your Name")
surname = input("Enter your Surname")
age = int(input("Enter your Age"))

print("User Name and Surname is",name, surname, "Age is", age)
# Out:
# Enter your Name Kelebogile
# Enter your Surname Seepe
# Enter your Age 20
# User Name and Surname is Kelebogile Seepe Age is 20

# %%
module = "Programming 511"
qalification = "Bsc In Information Technology" 
year = 2025

print( "My module is:", module, "with the qalification:", qalification, "in the year", 2025)
# Out:
# My module is: Programming 511 with the qalification: Bsc In Information Technology in the year 2025

# %%
number1 = 25
number2 = 75

anwer= number1 + number2
print(answer)
# Out:
# 110
